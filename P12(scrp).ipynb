# %% [markdown]
# import requests
# import bs4
# import pandas as pd
#
# request1 = requests.get('https://www.flipkart.com/lenovo-p2-grey-graphite-grey-32-gb/p/itmeq5ygebzgqgfb?pid=MOBEZFHHVD8KXE7G&lid=
#
# request1
#
# soup = bs4.BeautifulSoup(request1.text)
# soup
#
# soup.select('[class = "t-ZTKy"]')
#
# soup.select('for i in range(0,10):
#     print(soup.select('[class = "t-ZTKy"]')[i].text)
#     print()[class = "t-ZTKy"]')[0]
#
#
# soup.select('[class = "t-ZTKy"]')[0].text
#
# for i in range(0,10):
#     print(soup.select('[class = "t-ZTKy"]')[i].text)
#     print()
#
# review=[]
# for i in range (1,5):
#         rq = requests.get(f'https://www.flipkart.com/lenovo-p2-grey-graphite-grey-32-gb/product-reviews/itmeq5ygebzgqgfb?pid=MOBEZFHHVD8KXE7G&lid=LSTMOBEZFHHVD8KXE7GB0OS6I&marketplace=FLIPKART&page={i}')
#         print(rq)
#
#
# review=[]
# for i in range (1,5):
#         rq = requests.get(f'https://www.flipkart.com/lenovo-p2-grey-graphite-grey-32-gb/product-reviews/itmeq5ygebzgqgfb?pid=MOBEZFHHVD8KXE7G&lid=LSTMOBEZFHHVD8KXE7GB0OS6I&marketplace=FLIPKART&page={i}')
#         for j in range (0,10):
#             soup = bs4.BeautifulSoup(rq.text)
#             review.append(soup.select('[class = "t-ZTKy"]')[j].text)
#
# name = soup.select('[class = "_2sc7ZR _2V5EHH"]')
# name
#
# for i in range(0,10):
#     print(soup.select('[class = "_2sc7ZR _2V5EHH"]')[i].text)
#     print()
#
# cust_name = []
# for i in range (1,5):
#     rq = requests.get(f'https://www.flipkart.com/lenovo-p2-grey-graphite-grey-32-gb/product-reviews/itmeq5ygebzgqgfb?pid=MOBEZFHHVD8KXE7G&lid=LSTMOBEZFHHVD8KXE7GB0OS6I&marketplace=FLIPKART&page={i}')
#     for j in range (0,10):
#         soup = bs4.BeautifulSoup(rq.text)
#         cust_name.append(soup.select('[class = "_2sc7ZR _2V5EHH"]')[j].text)
#
#
# df = dict(zip(review, cust_name))
#
# data1 =  pd.DataFrame.from_dict(df, orient='index' )
# data1
#
# data1.to_csv('phone1.csv')
#
# import os
#
# pwd
#
# dfdata = pd.read_csv('phone1.csv')
# dfdata
